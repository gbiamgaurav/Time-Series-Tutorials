# %% [markdown]
# <a href="https://colab.research.google.com/github/gbiamgaurav/Time-Series-Tutorials/blob/main/PyCaret_Time_Series_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret-ts-alpha

# %%
from pycaret.datasets import get_data
data = get_data('airline')
# Out:
# Period
# 1949-01    112.0
# 1949-02    118.0
# 1949-03    132.0
# 1949-04    129.0
# 1949-05    121.0
# Freq: M, Name: Number of airline passengers, dtype: float64

# %%
data.plot()

# %%
from pycaret.time_series import *
s = setup(data, session_id = 123)
# Out:
#                     Description                    Value
# 0                    session_id                      123
# 1                 Original Data                 (144, 1)
# 2                Missing Values                    False
# 3         Transformed Train Set                   (143,)
# 4          Transformed Test Set                     (1,)
# 5                Fold Generator  ExpandingWindowSplitter
# 6                   Fold Number                        3
# 7   Enforce Prediction Interval                    False
# 8        Seasonal Period Tested                       12
# 9          Seasonality Detected                     True
# 10   Seasonality Used in Models                       12
# 11     Target Strictly Positive                     True
# 12           Target White Noise                       No
# 13                Recommended d                        1
# 14       Recommended Seasonal D                        1
# ...

# %%
check_stats()
# Out:
#             Test   Test Name  ...                   Setting        Value
# 0        Summary  Statistics  ...                                    144
# 1        Summary  Statistics  ...                                280.299
# 2        Summary  Statistics  ...                                  265.5
# 3        Summary  Statistics  ...                                119.966
# 4        Summary  Statistics  ...                                14391.9
# 5        Summary  Statistics  ...                              -0.364942
# 6        Summary  Statistics  ...                                0.58316
# 7        Summary  Statistics  ...                                    118
# 8    White Noise   Ljung-Box  ...  {'alpha': 0.05, 'K': 24}      1606.08
# 9    White Noise   Ljung-Box  ...  {'alpha': 0.05, 'K': 48}      1933.16
# 10   White Noise   Ljung-Box  ...  {'alpha': 0.05, 'K': 24}            0
# 11   White Noise   Ljung-Box  ...  {'alpha': 0.05, 'K': 48}            0
# ...

# %%
plot_model(plot = 'decomp_classical')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(plot = 'diagnostics')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(plot = 'acf')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(plot = 'pacf')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
best = compare_models()
# Out:
#                                                              Model      MAE  \
# exp_smooth                                   Exponential Smoothing    7.781
# knn_cds_dt         K Neighbors w/ Cond. Deseasonalize & Detrending  10.9141
# arima                                                        ARIMA  11.5951
# auto_arima                                              Auto ARIMA  13.0789
# rf_cds_dt        Random Forest w/ Cond. Deseasonalize & Detrending  14.5154
# llar_cds_dt      Lasso Least Angular Regressor w/ Cond. Deseaso...  14.5979
# et_cds_dt          Extra Trees w/ Cond. Deseasonalize & Detrending  15.0691
# theta                                             Theta Forecaster  16.0228
# gbr_cds_dt       Gradient Boosting w/ Cond. Deseasonalize & Det...  16.3259
# lightgbm_cds_dt  Light Gradient Boosting w/ Cond. Deseasonalize...  16.9467
# dt_cds_dt        Decision Tree w/ Cond. Deseasonalize & Detrending  18.1502
# ...

# %%
best
# Out:
# ExponentialSmoothing(damped_trend=False, initial_level=None,
#                      initial_seasonal=None, initial_trend=None,
#                      initialization_method='estimated', seasonal='mul', sp=12,
#                      trend='add', use_boxcox=None)

# %%
plot_model(best, plot = 'forecast', data_kwargs = {'fh': 24})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(best, plot = 'residuals')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(best, plot = 'insample')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
final_best = finalize_model(best)

# %%
save_model(final_best, 'my_best_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (ExponentialSmoothing(damped_trend=False, initial_level=None,
#                       initial_seasonal=None, initial_trend=None,
#                       initialization_method='estimated', seasonal='mul', sp=12,
#                       trend='add', use_boxcox=None), 'my_best_model.pkl')

# %%
loaded_model = load_model('my_best_model')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
predict_model(loaded_model, fh = 48)
# Out:
# 1961-01    445.2423
# 1961-02    418.2252
# 1961-03    465.3099
# 1961-04    494.9498
# 1961-05    505.4749
# 1961-06    573.3117
# 1961-07    663.5946
# 1961-08    654.9022
# 1961-09    546.7590
# 1961-10    488.4449
# 1961-11    415.7222
# 1961-12    460.3761
# 1962-01    474.0694
# 1962-02    445.1578
# 1962-03    495.1146
# 1962-04    526.4848
# 1962-05    537.5104
# 1962-06    609.4555
# 1962-07    705.2116
# 1962-08    695.7606
# 1962-09    580.6940
# 1962-10    518.6046
# 1962-11    441.2602
# 1962-12    488.5131
# 1963-01    502.8965
# 1963-02    472.0903
# 1963-03    524.9193
# 1963-04    558.0197
# 1963-05    569.5458
# 1963-06    645.5994
# 1963-07    746.8286
# 1963-08    736.6189
# 1963-09    614.6290
# 1963-10    548.7643
# 1963-11    466.7981
# 1963-12    516.6501
# 1964-01    531.7236
# 1964-02    499.0229
# 1964-03    554.7241
# 1964-04    589.5547
# 1964-05    601.5813
# 1964-06    681.7432
# 1964-07    788.4456
# 1964-08    777.4773
# 1964-09    648.5641
# ...
